# %% [markdown]
# **Laboratorio 2**
#
# ---
#
#
# *Series de tiempo*

# %% [markdown]
# **Saúl Contreras** 18409

# %%
path_consumo = "DatosConsumoCombustibles.csv"
path_importacion = "DatosImportacionCombustibles.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_consumo = pd.read_csv(path_consumo)
df_importacion = pd.read_csv(path_importacion)

# %% [markdown]
# ### Análisis Exploratorio

# %%
df_consumo.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  Anio  Mes  GasolinaSuper  GasolinaRegular  TotalGasolinas  \
# 0             3  2000    1      308156.82        202645.20       510802.02
# 1             4  2000    2      307766.31        205530.96       513297.27
# 2             5  2000    3      331910.29        229499.56       561409.85
# 3             6  2000    4      315648.08        210680.40       526328.48
# 4             7  2000    5      319667.97        208164.34       527832.31
# ..          ...   ...  ...            ...              ...             ...
# 252         194  2021    1      655503.47        685942.85      1341446.32
# 253         204  2021    2      621730.81        669313.36      1291044.17
# 254         214  2021    3      692228.61        679366.06      1371594.67
# 255         224  2021    4      610290.32        688389.15      1298679.47
# 256         234  2021    5      643104.75        707336.50      1350441.25
#
# ...

# %%
df_importacion.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  Anio  Mes  GasolinaSuper  GasolinaRegular  TotalGasolinas  \
# 0             3  2001    1      373963.96        177776.50       551740.46
# 1             4  2001    2      243091.07        123115.99       366207.06
# 2             5  2001    3      312084.38        161726.42       473810.80
# 3             6  2001    4      285054.89        127338.74       412393.63
# 4             7  2001    5      300913.67        168730.19       469643.86
# ..          ...   ...  ...            ...              ...             ...
# 240         316  2021    1      642652.37        626537.48      1269189.85
# 241         416  2021    2      726508.78        715261.34      1441770.12
# 242         516  2021    3      850334.64        772750.01      1623084.65
# 243          66  2021    4     1227173.53        634408.89      1861582.42
# 244          74  2021    5      673824.38        697161.30      1370985.68
#
# ...

# %%
df_consumo.head()
# Out:
#    Unnamed: 0  Anio  Mes  GasolinaSuper  GasolinaRegular  TotalGasolinas  \
# 0           3  2000    1      308156.82        202645.20       510802.02
# 1           4  2000    2      307766.31        205530.96       513297.27
# 2           5  2000    3      331910.29        229499.56       561409.85
# 3           6  2000    4      315648.08        210680.40       526328.48
# 4           7  2000    5      319667.97        208164.34       527832.31
#
#       Diesel  DieselLS  DieselULS  TotalDiesel  ...  AceitesLubricantes  \
# 0  634667.06       NaN        NaN    634667.06  ...                 NaN
# 1  642380.66       NaN        NaN    642380.66  ...                 NaN
# 2  699807.25       NaN        NaN    699807.25  ...                 NaN
# 3  586803.98       NaN        NaN    586803.98  ...                 NaN
# 4  656948.20       NaN        NaN    656948.20  ...                 NaN
#
#    GrasasLubricantes  Solventes  Naftas  Ceras  CrudoNacional  Butano  \
# ...

# %%
df_importacion.head()
# Out:
#    Unnamed: 0  Anio  Mes  GasolinaSuper  GasolinaRegular  TotalGasolinas  \
# 0           3  2001    1      373963.96        177776.50       551740.46
# 1           4  2001    2      243091.07        123115.99       366207.06
# 2           5  2001    3      312084.38        161726.42       473810.80
# 3           6  2001    4      285054.89        127338.74       412393.63
# 4           7  2001    5      300913.67        168730.19       469643.86
#
#       Diesel  DieselLS  DieselULS  TotalDiesel  ...  Solventes  Naftas  Ceras  \
# 0  566101.99       NaN        NaN    566101.99  ...        NaN     NaN    NaN
# 1  489525.80       NaN        NaN    489525.80  ...        NaN     NaN    NaN
# 2  575559.68       NaN        NaN    575559.68  ...        NaN     NaN    NaN
# 3  437745.42       NaN        NaN    437745.42  ...        NaN     NaN    NaN
# 4  552609.13       NaN        NaN    552609.13  ...        NaN     NaN    NaN
#
# ...

# %%
df_consumo.GasolinaRegular.dtypes
# Out:
# dtype('float64')

# %%
df_consumo.GasolinaSuper.dtypes
# Out:
# dtype('float64')

# %%
df_consumo.Diesel.dtypes
# Out:
# dtype('float64')

# %%
df_importacion.GasolinaRegular.dtypes
# Out:
# dtype('float64')

# %%
df_importacion.Diesel.dtypes
# Out:
# dtype('float64')

# %%
df_importacion.GasolinaSuper.dtypes
# Out:
# dtype('float64')

# %%
plt.hist(df_consumo.GasolinaRegular, color="turquoise")
# Out:
# (array([84., 61., 29.,  6., 18., 22., 13.,  7., 16.,  1.]),
#  array([160741.9  , 221487.013, 282232.126, 342977.239, 403722.352,
#         464467.465, 525212.578, 585957.691, 646702.804, 707447.917,
#         768193.03 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_consumo.GasolinaSuper, color="turquoise")
# Out:
# (array([24., 78., 65., 19., 10., 24., 25.,  9.,  2.,  1.]),
#  array([300242.78 , 346288.047, 392333.314, 438378.581, 484423.848,
#         530469.115, 576514.382, 622559.649, 668604.916, 714650.183,
#         760695.45 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_consumo.Diesel, color="turquoise")
# Out:
# (array([12., 23., 54., 43., 32., 23.,  8., 13.,  6.,  2.]),
#  array([ 507662.65 ,  578538.727,  649414.804,  720290.881,  791166.958,
#          862043.035,  932919.112, 1003795.189, 1074671.266, 1145547.343,
#         1216423.42 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_importacion.GasolinaRegular, color="turquoise")
# Out:
# (array([34., 70., 37., 26., 22., 23., 12., 13.,  5.,  3.]),
#  array([ 81015.3  , 162597.901, 244180.502, 325763.103, 407345.704,
#         488928.305, 570510.906, 652093.507, 733676.108, 815258.709,
#         896841.31 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_importacion.GasolinaSuper, color="turquoise")
# Out:
# (array([21., 63., 61., 53., 28., 16.,  2.,  0.,  0.,  1.]),
#  array([ 170292.5  ,  275980.603,  381668.706,  487356.809,  593044.912,
#          698733.015,  804421.118,  910109.221, 1015797.324, 1121485.427,
#         1227173.53 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_importacion.Diesel, color="turquoise")
# Out:
# (array([ 6., 23., 32., 46., 47., 24., 14.,  6.,  4.,  2.]),
#  array([ 229764.74 ,  366358.122,  502951.504,  639544.886,  776138.268,
#          912731.65 , 1049325.032, 1185918.414, 1322511.796, 1459105.178,
#         1595698.56 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# A través de este análisis exploratorio se pudo observar que todos los datos son de tipo flotante para las 3 variables, además de que no existen objetos de un tipo extraño que necesiten ser limpiados. Por otra parte a través de los histogramas podemos observar que las distribuciones de las mismas, siendo la de disel la única con distribución normal tanto par aimportación como para consumo

# %%
cols=["Anio","Mes"]
df_importacion['date'] = pd.to_datetime(df_importacion[cols].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns"), format='%Y-%m', errors='ignore')
df_consumo['date'] = pd.to_datetime(df_consumo[cols].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns"), format='%Y-%m', errors='ignore')

# %%
df_consumo.plot(x='date', y='GasolinaSuper', style='-')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_consumo.plot(x='date', y='GasolinaRegular', style='-')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_consumo.plot(x='date', y='Diesel', style='-')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_importacion.plot(x='date', y='GasolinaSuper', style='-')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_importacion.plot(x='date', y='GasolinaRegular', style='-')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_importacion.plot(x='date', y='Diesel', style='-')
# Out:
# <AxesSubplot:xlabel='date'>
